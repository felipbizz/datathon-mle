# %%
import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import pandas as pd
from src.config import load_config, get_abs_path

config = load_config()
paths = config["paths"]

df = pd.read_parquet(get_abs_path(paths["dataset_features"]))
df
# Out:
#        target  nivel_acad_desconhecido  nivel_acad_doutorado completo  \
# 0           0                    False                          False
# 1           0                    False                          False
# 2           1                    False                          False
# 3           0                    False                          False
# 4           0                    False                          False
# ...       ...                      ...                            ...
# 56697       0                    False                          False
# 56698       0                    False                          False
# 56699       0                    False                          False
# 56700       1                    False                          False
# 56701       0                    False                          False
#
#        nivel_acad_doutorado cursando  nivel_acad_ensino fundamental completo  \
# 0                              False                                   False
# 1                              False                                   False
# 2                              False                                   False
# 3                              False                                   False
# 4                              False                                   False
# ...                              ...                                     ...
# 56697                          False                                   False
# 56698                          False                                   False
# 56699                          False                                   False
# 56700                          False                                   False
# 56701                          False                                   False
#
#        nivel_acad_ensino medio completo  nivel_acad_ensino medio incompleto  \
# 0                                 False                               False
# 1                                 False                               False
# 2                                  True                               False
# 3                                  True                               False
# 4                                 False                               False
# ...                                 ...                                 ...
# 56697                             False                               False
# 56698                             False                               False
# 56699                             False                               False
# 56700                             False                               False
# 56701                             False                               False
#
#        nivel_acad_ensino superior completo  \
# 0                                     True
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 56697                                 True
# 56698                                 True
# 56699                                 True
# 56700                                 True
# 56701                                 True
#
#        nivel_acad_ensino superior cursando  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 56697                                False
# 56698                                False
# 56699                                False
# 56700                                False
# 56701                                False
#
#        nivel_acad_ensino superior incompleto  ...  demais_observacoes_emb_min  \
# 0                                      False  ...                   -0.161850
# 1                                      False  ...                   -0.161850
# 2                                      False  ...                   -0.185271
# 3                                      False  ...                   -0.185271
# 4                                      False  ...                   -0.153048
# ...                                      ...  ...                         ...
# 56697                                  False  ...                   -0.129788
# 56698                                  False  ...                   -0.177052
# 56699                                  False  ...                   -0.177052
# 56700                                  False  ...                   -0.177052
# 56701                                  False  ...                   -0.147268
#
#        demais_observacoes_emb_max  comentario_nchar  comentario_nwords  \
# 0                        0.117181                26                  5
# 1                        0.117181                48                  8
# 2                        0.210202                22                  5
# 3                        0.210202                12                  1
# 4                        0.165421                12                  1
# ...                           ...               ...                ...
# 56697                    0.161187                12                  1
# 56698                    0.497576                58                  7
# 56699                    0.497576                12                  1
# 56700                    0.497576                12                  1
# 56701                    0.168968                12                  1
#
#        comentario_emb_mean  comentario_emb_std  comentario_emb_min  \
# 0                -0.000235            0.051030           -0.176741
# 1                 0.000284            0.051030           -0.155262
# 2                 0.000357            0.051030           -0.165430
# 3                 0.000110            0.051031           -0.177052
# 4                 0.000110            0.051031           -0.177052
# ...                    ...                 ...                 ...
# 56697             0.000110            0.051031           -0.177052
# 56698             0.000314            0.051030           -0.126359
# 56699             0.000110            0.051031           -0.177052
# 56700             0.000110            0.051031           -0.177052
# 56701             0.000110            0.051031           -0.177052
#
#        comentario_emb_max  titulo_sim_ratio  sim_titulo_vs_vaga
# 0                0.204723          1.000000            1.000000
# 1                0.165039          1.000000            1.000000
# 2                0.155121          1.000000            1.000000
# 3                0.497576          1.000000            1.000000
# 4                0.497576          0.066667            0.188191
# ...                   ...               ...                 ...
# 56697            0.497576          0.250000            0.124156
# 56698            0.117563          1.000000            1.000000
# 56699            0.497576          1.000000            1.000000
# 56700            0.497576          1.000000            1.000000
# 56701            0.497576          0.181818            0.026507
#
# [56702 rows x 86 columns]

# %%
df = df.drop(columns=["target"])

caso_de_uma_pessoa_aleatoria = df.sample(1).values[0]
caso_de_uma_pessoa_aleatoria
# Out:
# array([False, False, False, False, False, False, True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, 270, 36,
#        -0.00019673847418744117, 0.051030658185482025,
#        -0.15069380402565002, 0.1759641021490097, 46, 6,
#        7.712122896919027e-05, 0.05103097856044769, -0.14528144896030426,
#        0.1422288864850998, 78, 11, 0.00020256008428987116,
#        0.051030635833740234, -0.12752993404865265, 0.19150573015213013,
#        45, 6, 0.00023983418941497803, 0.0510304756462574,
#        -0.20689177513122559, 0.12861959636211395, 1.0, 1.0], dtype=object)

# %%
import pickle

with open(paths["modelo_treinado"], "rb") as f:
    dados_carregados = pickle.load(f)

modelo = dados_carregados["model"]
imputer = dados_carregados["imputer"]
scaler = dados_carregados["scaler"]
features = dados_carregados["features"]

# %%
caso_imputer = imputer.transform([caso_de_uma_pessoa_aleatoria])[0]
caso_scaler = scaler.transform([caso_imputer])[0]
modelo.predict_proba([caso_scaler])
# Out:
# /home/felip/projetos/datathon-mle/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([[0.98, 0.02]])
